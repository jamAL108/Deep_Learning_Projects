# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers , models
import matplotlib.image as mpimg

# %% [markdown]
# ## Gathering Data from dataset Folder

# %% [markdown]
# ### Training Data

# %%
X =[]
Y =[]
target_size=(224,224)

# %%
def image_process(directory_path):
    image_paths = [f for f in os.listdir(directory_path) if f.endswith(('.jpg', '.png', '.jpeg'))]
    for image_path in image_paths:
        full_path = os.path.join(directory_path, image_path)
        img = Image.open(full_path)
        img = img.resize(target_size)
        img_array = np.array(img)
        normalized_image_data = (img_array * 255).astype(np.uint8)
        if "cat" in image_path:
            Y.append(0)
        elif "dog" in image_path:
            Y.append(1)
        X.append(normalized_image_data)

# %%
cat_path = "./Dataset/training_set/cats"
dog_path = "./Dataset/training_set/dogs"
# for cat
image_process(cat_path)
# for dogs
image_process(dog_path)

# %% [markdown]
# ### Test Data

# %%
cat_path = "./Dataset/test_set/cats"
dog_path = "./Dataset/test_set/dogs"
# for cat
image_process(cat_path)
# for dogs
image_process(dog_path)

# %%
X = np.array(X)
Y = np.array(Y)

# %%
image_pil = Image.fromarray(X[1000])
display(image_pil)
print(Y[1000])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# 0

# %%
X.shape
# Out:
# (10028, 224, 224, 3)

# %%
X_train , X_test ,y_train , y_test = train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
X_train.shape
# Out:
# (7521, 224, 224, 3)

# %%
y_train.shape
# Out:
# (7521,)

# %%
display(Image.fromarray(X_train[5]))
print(y_train[5])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# 1

# %%
X_train_scaled = X_train/255
X_test_scaled = X_test/255

# %%
model = models.Sequential([
    # convo layer
    layers.Conv2D(filters=32,kernel_size=(3,3),activation='relu', input_shape=(224,224,3)),
    layers.MaxPooling2D((2,2)),
    
    layers.Conv2D(filters=64,kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    
    # Dense
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(1,activation='sigmoid')
])

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy'])
model.fit(X_train_scaled , y_train,epochs=5)
# Out:
# Epoch 1/5
# 236/236 [==============================] - 227s 946ms/step - loss: 0.7415 - accuracy: 0.5490
# Epoch 2/5
# 236/236 [==============================] - 227s 962ms/step - loss: 0.6439 - accuracy: 0.6326
# Epoch 3/5
# 236/236 [==============================] - 221s 935ms/step - loss: 0.5456 - accuracy: 0.7151
# Epoch 4/5
# 236/236 [==============================] - 209s 885ms/step - loss: 0.4259 - accuracy: 0.8019
# Epoch 5/5
# 236/236 [==============================] - 193s 818ms/step - loss: 0.2859 - accuracy: 0.8737

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 79/79 [==============================] - 20s 242ms/step - loss: 0.6865 - accuracy: 0.7184
# [0.6864567995071411, 0.7183884978294373]

# %% [markdown]
# ### Training on Sample Data >....< Letssss gooooooo.

# %%
def image_proc(image_path):
    target_size=(224,224)
    img = Image.open(image_path)
    img = img.resize(target_size)
    img_array = np.array(img)
    normalized_image_data = (img_array * 255).astype(np.uint8)
    normalized_image=normalized_image_data/255
    return normalized_image

# %%
lists = [ './sample_image_for_test/cat1.jpeg' ,'./sample_image_for_test/cat2.jpg' , './sample_image_for_test/dog1.jpg' , './sample_image_for_test/dog2.jpg' ]
for path in lists:
    img = np.array(image_proc(path))
    print(img.shape)
    img = np.expand_dims(img, axis=0) 
    y_pred = model.predict(img)
    if y_pred>=0.5:
        print("The predicted animal is : dog")
    elif y_pred<0.5:
        print("The predicted animal is : cat")
    fig, ax = plt.subplots(figsize=(3, 3))  # Set the figure size as desired
    img = mpimg.imread(path)
    ax.imshow(img)
    ax.axis('off')  # Turn off axis labels and ticks for cleaner display
    plt.show()
# Out:
# (224, 224, 3)
# 1/1 [==============================] - 0s 32ms/step
# The predicted animal is : cat
# (224, 224, 3)
# 1/1 [==============================] - 0s 33ms/step
# The predicted animal is : cat
# (224, 224, 3)
# 1/1 [==============================] - 0s 36ms/step
# The predicted animal is : dog
# (224, 224, 3)
# 1/1 [==============================] - 0s 35ms/step
# The predicted animal is : dog

# %% [markdown]
# ### The End Thanku
